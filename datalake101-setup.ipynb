# %% [markdown]
# # Setup the environment
# Installing the boto3 library is required to connect to S3 and access Parquet or CSV files.
# Loading credentials from .env

# %%
# install  some libraries
! pip install boto3

# %%
# we need to read credentials from .env file
! pip install python-dotenv

# %%
# %load_ext dotenv
# %dotenv
import os
ACCESS_KEY = os.environ.get("ACCESS_KEY")
SECRET_KEY = os.environ.get("SECRET_KEY")
END_POINT = os.environ.get("END_POINT")

# %%
SECRET_KEY
#ACCESS_KEY
# Out:
# 'dpp9zvprD0Q0AEdRqifYKVONKAzGj839'

# %%
# Create S3 Client
# boto3 werkt niet lijkt het
import boto3

s3_client = boto3.client('s3',
                         endpoint_url = "https://"+END_POINT,
                         aws_access_key_id = ACCESS_KEY,
                         aws_secret_access_key = SECRET_KEY,
                         config=boto3.session.Config(signature_version='s3v4')
)

# %%
# Create a bucket
s3_client.list_buckets()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Create a bucket
# ----> 2 s3_client.list_buckets()
#
# File ~/git/datalake101/.datalake101/lib/python3.10/site-packages/botocore/client.py:565, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     561     raise TypeError(
#     562         f"{py_operation_name}() only accepts keyword arguments."
#     563     )
#     564 # The "self" in this scope is referring to the BaseClient.
# --> 565 return self._make_api_call(operation_name, kwargs)
#
# File ~/git/datalake101/.datalake101/lib/python3.10/site-packages/botocore/client.py:1001, in BaseClient._make_api_call(self, operation_name, api_params)
#     997     maybe_compress_request(
#     998         self.meta.config, request_dict, operation_model
#     999     )
#    1000     apply_request_checksum(request_dict)
# ...

# %%
# minio python sdk
! pip install minio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 KB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 6.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#   Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 KB 7.5 MB/s eta 0:00:00
# ...
#   Using cached cffi-1.16.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (443 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.6/117.6 KB 8.8 MB/s eta 0:00:00
# ...

# %%
import os

os.environ['SSL_CERT_FILE'] = r'./cert.crt'

# %%
from minio import Minio

# Initialize MinIO client
client = Minio("s3.vezel14.org",
               access_key=ACCESS_KEY,
               secret_key=SECRET_KEY,
                secure=True
)

# %%
import sys
#Minio.trace_on()
client.trace_on(sys.stdout)

# %%
from minio import Minio

client = Minio("play.min.io",
    access_key="Q3AM3UQ867SPQQA43P2F",
    secret_key="zuf+tfteSlswRu7BJ86wekitnifILbZam1KYY3TG"
)

# %%
client.list_buckets()
# Out:
# ---------START-HTTP---------
# GET / HTTP/1.1
# Host: s3.vezel14.org
# User-Agent: MinIO (Linux; x86_64) minio-py/7.2.7
# X-Amz-Content-Sha256: UNSIGNED-PAYLOAD
# X-Amz-Date: 20240503T194222Z
# Authorization: AWS4-HMAC-SHA256 Credential=*REDACTED*/20240503/us-east-1/s3/aws4_request, SignedHeaders=host;x-amz-content-sha256;x-amz-date, Signature=*REDACTED*
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 client.list_buckets()
#
# File ~/git/datalake101/.datalake101/lib/python3.10/site-packages/minio/api.py:677, in Minio.list_buckets(self)
#     665 def list_buckets(self) -> list[Bucket]:
#     666     """
#     667     List information of all accessible buckets.
#     668
#    (...)
#     674             print(bucket.name, bucket.creation_date)
#     675     """
# --> 677     response = self._execute("GET")
# ...

# %%
import urllib3
import minio

httpClient = urllib3.PoolManager(
                cert_reqs="CERT_NONE")

__client = minio.Minio("s3.vezel14.org",
                access_key=ACCESS_KEY,
                secret_key=SECRET_KEY,
                secure=True,
                http_client=httpClient)

# %%
import sys
#Minio.trace_on()
__client.trace_on(sys.stdout)

# %%
__client.list_buckets()
# Out:
# ---------START-HTTP---------
# GET / HTTP/1.1
# Host: s3.vezel14.org
# User-Agent: MinIO (Linux; x86_64) minio-py/7.2.7
# X-Amz-Content-Sha256: UNSIGNED-PAYLOAD
# X-Amz-Date: 20240503T190834Z
# Authorization: AWS4-HMAC-SHA256 Credential=*REDACTED*/20240503/us-east-1/s3/aws4_request, SignedHeaders=host;x-amz-content-sha256;x-amz-date, Signature=*REDACTED*
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 __client.list_buckets()
#
# File ~/git/datalake101/.datalake101/lib/python3.10/site-packages/minio/api.py:677, in Minio.list_buckets(self)
#     665 def list_buckets(self) -> list[Bucket]:
#     666     """
#     667     List information of all accessible buckets.
#     668
#    (...)
#     674             print(bucket.name, bucket.creation_date)
#     675     """
# --> 677     response = self._execute("GET")
# ...

# %%
from minio import Minio
import urllib3
from datetime import timedelta
import sys


timeout = timedelta(minutes=5).seconds

http_client = urllib3.PoolManager(
timeout=urllib3.util.Timeout(connect=timeout, read=timeout),
        maxsize=10,
        cert_reqs='CERT_REQUIRED',
        ca_certs=r'./cert.crt2',
        retries=urllib3.Retry(
            total=5,
            backoff_factor=0.2,
            status_forcelist=[500, 502, 503, 504]
        )
)

client = Minio('s3.vezel14.org',
                access_key=ACCESS_KEY,
                secret_key=SECRET_KEY,
                secure=True,
                http_client=http_client)

client.trace_on(sys.stdout)

bucket_list = client.list_buckets()

for bucket in bucket_list:
    print(bucket.name)
# Out:
# ---------START-HTTP---------
# GET / HTTP/1.1
# Host: s3.vezel14.org
# User-Agent: MinIO (Linux; x86_64) minio-py/7.2.7
# X-Amz-Content-Sha256: UNSIGNED-PAYLOAD
# X-Amz-Date: 20240503T191818Z
# Authorization: AWS4-HMAC-SHA256 Credential=*REDACTED*/20240503/us-east-1/s3/aws4_request, SignedHeaders=host;x-amz-content-sha256;x-amz-date, Signature=*REDACTED*
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 29
#      21 client = Minio('s3.vezel14.org',
#      22                 access_key=ACCESS_KEY,
#      23                 secret_key=SECRET_KEY,
#      24                 secure=True,
#      25                 http_client=http_client)
#      27 client.trace_on(sys.stdout)
# ---> 29 bucket_list = client.list_buckets()
#      31 for bucket in bucket_list:
#      32     print(bucket.name)
#
# ...
