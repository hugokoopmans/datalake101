# %% [markdown]
# ### Set up environment variables

# %%
! pip install matplotlib
! pip install s3fs
! pip install seaborn
! pip install yfinance
! pip install pyarrow
# Out:
# Requirement already satisfied: matplotlib in ./.datalake101/lib/python3.10/site-packages (3.8.4)
# Requirement already satisfied: python-dateutil>=2.7 in ./.datalake101/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.datalake101/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: pillow>=8 in ./.datalake101/lib/python3.10/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: cycler>=0.10 in ./.datalake101/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in ./.datalake101/lib/python3.10/site-packages (from matplotlib) (24.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./.datalake101/lib/python3.10/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: numpy>=1.21 in ./.datalake101/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.datalake101/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in ./.datalake101/lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: six>=1.5 in ./.datalake101/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: s3fs in ./.datalake101/lib/python3.10/site-packages (2024.3.1)
# Requirement already satisfied: fsspec==2024.3.1 in ./.datalake101/lib/python3.10/site-packages (from s3fs) (2024.3.1)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in ./.datalake101/lib/python3.10/site-packages (from s3fs) (2.12.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in ./.datalake101/lib/python3.10/site-packages (from s3fs) (3.9.5)
# Requirement already satisfied: botocore<1.34.70,>=1.34.41 in ./.datalake101/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.34.69)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in ./.datalake101/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (0.11.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in ./.datalake101/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs) (1.16.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.datalake101/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (6.0.5)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.datalake101/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./.datalake101/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in ./.datalake101/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.datalake101/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.4.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.datalake101/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.9.4)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in ./.datalake101/lib/python3.10/site-packages (from botocore<1.34.70,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs) (2.2.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./.datalake101/lib/python3.10/site-packages (from botocore<1.34.70,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in ./.datalake101/lib/python3.10/site-packages (from botocore<1.34.70,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs) (2.9.0.post0)
# Requirement already satisfied: idna>=2.0 in ./.datalake101/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.7)
# Requirement already satisfied: six>=1.5 in ./.datalake101/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.34.70,>=1.34.41->aiobotocore<3.0.0,>=2.5.4->s3fs) (1.16.0)
# Requirement already satisfied: seaborn in ./.datalake101/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: pandas>=1.2 in ./.datalake101/lib/python3.10/site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./.datalake101/lib/python3.10/site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in ./.datalake101/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: cycler>=0.10 in ./.datalake101/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.datalake101/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: pillow>=8 in ./.datalake101/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.datalake101/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in ./.datalake101/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.datalake101/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: packaging>=20.0 in ./.datalake101/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./.datalake101/lib/python3.10/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.51.0)
# Requirement already satisfied: pytz>=2020.1 in ./.datalake101/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.datalake101/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in ./.datalake101/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: yfinance in ./.datalake101/lib/python3.10/site-packages (0.2.38)
# Requirement already satisfied: pandas>=1.3.0 in ./.datalake101/lib/python3.10/site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: appdirs>=1.4.4 in ./.datalake101/lib/python3.10/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: lxml>=4.9.1 in ./.datalake101/lib/python3.10/site-packages (from yfinance) (5.2.1)
# Requirement already satisfied: pytz>=2022.5 in ./.datalake101/lib/python3.10/site-packages (from yfinance) (2024.1)
# Requirement already satisfied: numpy>=1.16.5 in ./.datalake101/lib/python3.10/site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: multitasking>=0.0.7 in ./.datalake101/lib/python3.10/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: requests>=2.31 in ./.datalake101/lib/python3.10/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: peewee>=3.16.2 in ./.datalake101/lib/python3.10/site-packages (from yfinance) (3.17.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in ./.datalake101/lib/python3.10/site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in ./.datalake101/lib/python3.10/site-packages (from yfinance) (1.1)
# Requirement already satisfied: frozendict>=2.3.4 in ./.datalake101/lib/python3.10/site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: soupsieve>1.2 in ./.datalake101/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: webencodings in ./.datalake101/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: six>=1.9 in ./.datalake101/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.datalake101/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in ./.datalake101/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.datalake101/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in ./.datalake101/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2024.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.datalake101/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.datalake101/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.7)
# Collecting pyarrow
#   Downloading pyarrow-16.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 5.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: numpy>=1.16.6 in ./.datalake101/lib/python3.10/site-packages (from pyarrow) (1.26.4)
# Installing collected packages: pyarrow
# Successfully installed pyarrow-16.0.0

# %%
import json
import os

# Load the credentials and connection information.
with open('credentials.json') as f:
    credentials = json.load(f)

os.environ['MINIO_URL'] = credentials['MINIO_URL']
os.environ['MINIO_ACCESS_KEY'] = credentials['MINIO_ACCESS_KEY']
os.environ['MINIO_SECRET_ACCESS_KEY'] = credentials['MINIO_SECRET_KEY']

# %% [markdown]
# ### Downloading Market Data

# %%
import datetime
import yfinance as yf

start_date = datetime.datetime(2023, 1, 1)
end_date = datetime.datetime(2023, 12, 31)
download_dir = os.path.join(os.getcwd(), 'marketdata')

magnificient_seven = ['AAPL', 'AMZN', 'GOOGL', 'META', 'MSFT', 'NVDA', 'TSLA']
for ticker_string in magnificient_seven:
    ticker = yf.Ticker(ticker_string)
    historical_data = ticker.history(start=start_date, end=end_date)
    file_path = os.path.join(download_dir, f'{ticker_string}.parquet')
    historical_data.to_parquet(file_path)
    print(f'{ticker_string} downloaded.')
# Out:
# AAPL downloaded.
# AMZN downloaded.
# GOOGL downloaded.
# META downloaded.
# MSFT downloaded.
# NVDA downloaded.
# TSLA downloaded.

# %% [markdown]
# ### Set up an S3 Connection

# %%
from s3fs import S3FileSystem
import os

key = os.environ['MINIO_ACCESS_KEY']
secret = os.environ['MINIO_SECRET_ACCESS_KEY']
endpoint_url = os.environ['MINIO_URL']

s3 = S3FileSystem(anon=False, endpoint_url=endpoint_url, 
                  key=key, 
                  secret=secret, 
                  use_ssl=True)

# %% [markdown]
# ### Creating a Bucket

# %%
s3.ls('hugosbucket')
# Out:
# ['hugosbucket/bunkhouse', 'hugosbucket/chat4bi.png']

# %%
bucket_name = 'market-data'
if not s3.exists(bucket_name):
    s3.makedir(f's3://{bucket_name}', exist_ok=True)

# %% [markdown]
# ### Uploading Market Data

# %%
magnificient_seven = ['AAPL', 'AMZN', 'GOOGL', 'META', 'MSFT', 'NVDA', 'TSLA']
for ticker_string in magnificient_seven:
    local_file_path = os.path.join(download_dir, f'{ticker_string}.parquet')
    remote_object_path = f'{bucket_name}/{ticker_string}.parquet'
    s3.put_file(local_file_path, remote_object_path)
    print(f'{ticker_string} uploaded.')
# Out:
# AAPL uploaded.
# AMZN uploaded.
# GOOGL uploaded.
# META uploaded.
# MSFT uploaded.
# NVDA uploaded.
# TSLA uploaded.

# %% [markdown]
# ### Listing Objects

# %%
object_list = s3.ls(f's3://{bucket_name}', detail=False)
object_list
# Out:
# ['market-data/AAPL.parquet',
#  'market-data/AMZN.parquet',
#  'market-data/GOOGL.parquet',
#  'market-data/META.parquet',
#  'market-data/MSFT.parquet',
#  'market-data/NVDA.parquet',
#  'market-data/TSLA.parquet']

# %% [markdown]
# ### Pandas DataFrame integration

# %%
import pandas as pd

ticker_string = 'NVDA'
storage_options={
    'key': key,
    'secret': secret,
    'endpoint_url': endpoint_url,
}
historical_data = pd.read_parquet(f's3://{bucket_name}/{ticker_string}.parquet', storage_options=storage_options)
historical_data.tail(10)
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2023-12-15 00:00:00-05:00  481.917410  494.016849  481.177454  488.877075
# 2023-12-18 00:00:00-05:00  493.976819  504.306321  491.476936  500.746490
# 2023-12-19 00:00:00-05:00  494.216820  496.976701  488.927090  496.016754
# 2023-12-20 00:00:00-05:00  496.526680  499.966521  480.957434  481.087402
# 2023-12-21 00:00:00-05:00  488.087090  490.926983  484.167291  489.877014
# 2023-12-22 00:00:00-05:00  491.926922  493.806808  484.647265  488.277069
# 2023-12-26 00:00:00-05:00  489.657037  495.976748  489.577054  492.766907
# 2023-12-27 00:00:00-05:00  495.086748  496.776671  490.826969  494.146820
# 2023-12-28 00:00:00-05:00  496.406712  498.816603  494.096823  495.196777
# 2023-12-29 00:00:00-05:00  498.106645  499.946555  487.487147  495.196777
#
#                              Volume  Dividends  Stock Splits
# Date
# 2023-12-15 00:00:00-05:00  47947800        0.0           0.0
# 2023-12-18 00:00:00-05:00  41258700        0.0           0.0
# 2023-12-19 00:00:00-05:00  46444400        0.0           0.0
# 2023-12-20 00:00:00-05:00  39789400        0.0           0.0
# 2023-12-21 00:00:00-05:00  30042500        0.0           0.0
# 2023-12-22 00:00:00-05:00  25213900        0.0           0.0
# 2023-12-26 00:00:00-05:00  24420000        0.0           0.0
# 2023-12-27 00:00:00-05:00  23364800        0.0           0.0
# 2023-12-28 00:00:00-05:00  24658700        0.0           0.0
# 2023-12-29 00:00:00-05:00  38869000        0.0           0.0

# %%
storage_options={
    'key': key,
    'secret': secret,
    'endpoint_url': endpoint_url,
}

magnificient_seven = ['AAPL', 'AMZN', 'GOOGL', 'META', 'MSFT', 'NVDA', 'TSLA']

df_list = []
for ticker_string in magnificient_seven:
    new_data = pd.read_parquet(f's3://{bucket_name}/{ticker_string}.parquet', storage_options=storage_options)
    new_data['Ticker'] = ticker_string
    df_list.append(new_data[['Ticker', 'Close']])

historical_data = pd.concat(df_list, axis=0)
historical_data[historical_data['Ticker']=='AMZN'].head()
# Out:
#                           Ticker      Close
# Date
# 2023-01-03 00:00:00-05:00   AMZN  85.820000
# 2023-01-04 00:00:00-05:00   AMZN  85.139999
# 2023-01-05 00:00:00-05:00   AMZN  83.120003
# 2023-01-06 00:00:00-05:00   AMZN  86.080002
# 2023-01-09 00:00:00-05:00   AMZN  87.360001

# %%
historical_data = historical_data.reset_index()
pt = historical_data.pivot(columns='Ticker', index='Date', values='Close')
pt.head()
# Out:
# Ticker                           AAPL       AMZN      GOOGL        META  \
# Date
# 2023-01-03 00:00:00-05:00  124.216293  85.820000  89.120003  124.607788
# 2023-01-04 00:00:00-05:00  125.497498  85.139999  88.080002  127.235008
# 2023-01-05 00:00:00-05:00  124.166641  83.120003  86.199997  126.805458
# 2023-01-06 00:00:00-05:00  128.735245  86.080002  87.339996  129.882202
# 2023-01-09 00:00:00-05:00  129.261627  87.360001  88.019997  129.332779
#
# Ticker                           MSFT        NVDA        TSLA
# Date
# 2023-01-03 00:00:00-05:00  237.036011  143.079788  108.099998
# 2023-01-04 00:00:00-05:00  226.667282  147.417679  113.639999
# 2023-01-05 00:00:00-05:00  219.949371  142.580048  110.339996
# 2023-01-06 00:00:00-05:00  222.541565  148.517120  113.059998
# 2023-01-09 00:00:00-05:00  224.708298  156.203369  119.769997

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Use Seaborn to set the style.
sns.set_style('ticks')

# Plot all the close prices as cumulutive closing values.
((pt.pct_change()+1).cumprod()).plot(figsize=(10, 7))
plt.legend()
plt.title('The Magnificient Seven')

# Define the labels
plt.ylabel('Cumulative Close Value')
plt.xlabel('Date')

# Plot the grid lines
plt.grid(True)
sns.despine()
plt.show()

# %%
# Define the ticker list
import pandas as pd
tickers_list = ['AAPL', 'WMT', 'IBM', 'MU', 'BA', 'AXP']

# Fetch the data
data = yf.download(tickers_list,'2023-1-1')['Adj Close']
data.head()

# %% [markdown]
# ### Other methods of the yfinance Ticker object.

# %%
msft = yf.Ticker("MSFT")

# get all stock info
msft.info

# get historical market data
hist = msft.history(period="1mo")

# show meta information about the history (requires history() to be called first)
msft.history_metadata

# show actions (dividends, splits, capital gains)
msft.actions
msft.dividends
msft.splits
msft.capital_gains  # only for mutual funds & etfs

# show share count
msft.get_shares_full(start="2022-01-01", end=None)

# show financials:
# - income statement
msft.income_stmt
msft.quarterly_income_stmt
# - balance sheet
msft.balance_sheet
msft.quarterly_balance_sheet
# - cash flow statement
msft.cashflow
msft.quarterly_cashflow
# see `Ticker.get_income_stmt()` for more options

# show holders
msft.major_holders
msft.institutional_holders
msft.mutualfund_holders
msft.insider_transactions
msft.insider_purchases
msft.insider_roster_holders

# show recommendations
msft.recommendations
msft.recommendations_summary
msft.upgrades_downgrades

# Show future and historic earnings dates, returns at most next 4 quarters and last 8 quarters by default. 
# Note: If more are needed use msft.get_earnings_dates(limit=XX) with increased limit argument.
msft.earnings_dates

# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
msft.isin

# show options expirations
msft.options

# show news
msft.news

# get option chain for specific expiration
opt = msft.option_chain('YYYY-MM-DD')
# data available via: opt.calls, opt.puts
